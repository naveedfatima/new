# %%
# %pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.iloc[3,4]
# Out:
# 'female'

# %%
x=df['Age']

# %%
y=['Fare']

# %%
import matplotlib.pyplot as plt

# %%
x=df['Age']
y=df['Fare']
plt.scatter(x, y, color='red', label='Age')
plt.scatter(x, y, color='green', label='Fare', alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('scatter plot of Fare and Age')
plt.legend(['Age(red)', 'Fare(green)'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Droping Columns

# %%
columns = ['Ticket', 'Cabin', 'Name']

# %%
df = df.drop(columns, axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %% [markdown]
# Looking for null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# Replacing nan value in Age by median

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %% [markdown]
# replacing nan value in Embarked colummn by mode

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Replacing female by "1" and male by "0" values in sex colummn

# %%
df['Gender'] = df['Sex'].map({'female': 0, 'male': 1}).astype(int)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked  Gender
# 0          S       1
# 1          C       0
# 2          S       0
# ...

# %% [markdown]
# Cmparing Age and fare graphically

# %%
x=df['Age']
y=df['Fare']
plt.scatter(x, y, edgecolors='black', facecolor='yellow')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('scatter plot of Fare and Age')
plt.show()

# %%
x=df['Age']
y=df['Fare']
colors=['red' if age >30 else 'green' for age in x]
plt.scatter(x, y, c=colors)
plt.xlabel('Age (red if > 30)')
plt.ylabel('Fare (green if <= 30)')
plt.title('scatter plot of Fare and Age')
plt.show()

# %%
x = df['Age']
y = df['Fare']
def colors(col):
    if 1 <= col['Age'] <= 10:
        return 'green'
    elif 11 < col['Age'] <= 20:
        return 'yellow'
    elif 20 < col['Age'] <= 30:
        return 'orange'
    elif 30 < col['Age'] <= 40:
        return 'red'
    elif 40 < col['Age'] <= 50:
        return 'blue'
    elif 50 < col['Age'] <= 60:
        return 'black'
    elif 60 < col['Age'] <= 70:
        return 'pink'
    elif 70 < col['Age'] <= 80:
        return 'brown'
    elif 80 < col['Age'] <= 90:
        return 'purple'
    elif 90 < col['Age'] <= 100:
        return 'aqua'
    else:
        return 'navy'

# %%
df['color'] = df.apply(colors, axis=1)

# %%
plt.scatter(x, y, c=df['color'])
plt.title('Scatter Plot of Age vs Fare', fontsize=14)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([1,2,3,4])
plt.bar(x,y)
plt.show()

# %%
x=["Apples", "Bananas"]
y=[400,600]
plt.bar(x,y)
plt.show()

# %%
x=["Apples", "Bananas"]
y=[400,600]
plt.barh(x,y)
plt.show()

# %%
x=["Apples", "Bananas", "oranges"]
y=[400,600,300]
plt.bar(x,y, color=['red','yellow','orange'], width=0.2)
plt.show()

# %%
# distribution of passenagers by class
class_counts= df['Pclass'].value_counts()
                 
class_counts.plot(kind='bar', color = ['blue', 'green', 'red'])
plt.xlabel("Passenger Class")
plt.ylabel("No. of Passengers")
plt.title("Number of Passengers by Class")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked  Gender   color
# 0          S       1  orange
# 1          C       0     red
# ...

# %%
# distribution of passenagers by class
class_counts= df['Survived'].value_counts()
                 
class_counts.plot(kind='bar', color = ['blue', 'green'])
plt.xlabel("Surrvied")
plt.ylabel("no.of pasengers")
plt.title("Data")
plt.xticks(ticks=[0,1], labels=['not survived', 'survived'])
plt.yticks(ticks=[0,100,200,300,400,500,600], labels=['zero', 'one hundred', 'two hundred', 'three hundred', 'four hundred', 'five hundred', 'six hundred'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # matplotlib pie

# %%
y = np.array([35,25,25,15])
mylabels = ["apples", "bananas","cherries", "dates"]
plt.pie(y, labels = mylabels, startangle=90)
plt.show()

# %%
y = np.array([35,25,25,15])
mylabels = ["apples", "bananas","cherries", "dates"]
myexplode = [0.2, 0.3, 0.3, 0]
plt.pie(y, labels = mylabels, explode= myexplode, shadow= True)
plt.legend()
plt.show()

# %%
class_counts = df['Pclass'].value_counts()
plt.figure(figsize= (8,8))
